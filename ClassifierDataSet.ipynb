# %%
from src.process.inference_process import inference
import matplotlib.pyplot as plt

# %%
path_models = './data/forms_ref/'
path_img = './data/test/2042_K_recto/SIP_00007_1_R.jpg'

match_form, keypoints, image = inference(test_image_path=path_img, path_models=path_models)

plt.figure(figsize=(12,10))
plt.imshow(image)
plt.axis('off')
plt.title('Transformed Image')
plt.show()
# Out:
# ==> Initializing SuperPoint...
# ==> SuperPoint initialized. Time taken: 0.04 seconds.
# ==> Loading descriptors...
# ==> Descriptors loaded. Time taken: 0.12 seconds.
# ==> Starting inference phase...
# ==> Finding best matching form for image: ./data/test/2042_K_recto/SIP_00007_1_R.jpg...
# ==> Processing image: ./data/test/2042_K_recto/SIP_00007_1_R.jpg...
# ==> Finished processing image. Time taken: 3.40 seconds.
# 401 good matches found for form 2042_Kauto_recto.
# 36 good matches found for form 2042_Kauto_verso.
# 909 good matches found for form 2042_K_recto.
# 36 good matches found for form 2042_K_verso.
# 129 good matches found for form 2042_recto.
# 16 good matches found for form 2042_verso.
# (3, 8725)
# (3, 1000)
# (3, 1000)
# ==> Best matching form found. Time taken: 3.95 seconds.
# The best matching form for the test image is 2042_K_recto.
# ==> Inference phase completed. Total time taken: 3.95 seconds.

# %%
from src.ocr.ocr_process import draw_boxes


img, strings, df = draw_boxes(image, match_form, 5)
plt.figure(figsize=(12,10))
plt.imshow(img)
plt.axis('off')
plt.title('Transformed Image')
plt.show()
# Out:
# x: 1161.2231594985012
# y: 584.4688198002896
# width: 47.97828714839364
# height: 27.255022684987754
# labels: ['G']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 4
#       1 from src.ocr.ocr_process import draw_boxes
# ----> 4 img, strings, df = draw_boxes(image, match_form, 5)
#       5 plt.figure(figsize=(12,10))
#       6 plt.imshow(img)
#
# File /mnt/c/Users/Utilizador/Desktop/PFEE-new/FormRecognizer-SuperPointOCR/src/ocr/ocr_process.py:76, in draw_boxes(img_path, good_forms, nb_ocr)
#      73 with open(full_path_json, 'r') as json_file:
#      74     data = json.load(json_file)
# ---> 76 img, strings, df = draw_boxes_on_image(img_path, data, nb_ocr)
#      78 return img, strings, df
#
# File /mnt/c/Users/Utilizador/Desktop/PFEE-new/FormRecognizer-SuperPointOCR/src/ocr/ocr_process.py:46, in draw_boxes_on_image(image, json_data, nb_ocr)
# ...
